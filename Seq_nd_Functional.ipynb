# %% [markdown]
# <a href="https://colab.research.google.com/github/salim-hbk/ai-ml/blob/main/Seq_nd_Functional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.python.keras.utils.vis_utils import plot_model
import pydot
from tensorflow.keras.models import Model

# %%
def build_sequential_model():
  seq_model = tf.keras.Sequential()
  seq_model.add(tf.keras.layers.Flatten(input_shape=(28,28)))
  seq_model.add(tf.keras.layers.Dense(128, activation='relu'))
  seq_model.add(tf.keras.layers.Dense(10, activation='softmax'))
  return seq_model

# %%
def build_fun_model():
  fun_model = tf.keras.layers.Input(shape=(28,28))
  x = tf.keras.layers.Flatten()(fun_model)
  x= tf.keras.layers.Dense(128, activation='relu')(x)
  output_layer = tf.keras.layers.Dense(10, activation='softmax')(x)
  model = tf.keras.models.Model(inputs=fun_model, outputs=output_layer)
  return model

# %%
model = build_fun_model()
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
model = build_sequential_model()
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
mnits = tf.keras.datasets.fashion_mnist
(trainX, trainY), (testX, testY) =mnits.load_data()

# %%
import matplotlib.pyplot as plt

for i in range(8):
  plt.subplot(2,4, i+1)
  plt.imshow(trainX[i], cmap='gray_r')

# %%
trainX = trainX/255.0
testX = testX/255.0
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(trainX, trainY, epochs=20)
model.evaluate(testX, testY)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.6365 - accuracy: 0.7792
# Epoch 2/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3801 - accuracy: 0.8632
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3427 - accuracy: 0.8736
# Epoch 4/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3105 - accuracy: 0.8870
# Epoch 5/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2957 - accuracy: 0.8909
# Epoch 6/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2806 - accuracy: 0.8962
# Epoch 7/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2686 - accuracy: 0.9014
# Epoch 8/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2571 - accuracy: 0.9047
# Epoch 9/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2460 - accuracy: 0.9078
# Epoch 10/20
# ...

# %% [markdown]
# Lets build a functional model

# %%
model = build_fun_model()
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(trainX, trainY, epochs=20)
model.evaluate(testX, testY)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.6363 - accuracy: 0.7843
# Epoch 2/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3879 - accuracy: 0.8586
# Epoch 3/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3405 - accuracy: 0.8777
# Epoch 4/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.3159 - accuracy: 0.8845
# Epoch 5/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2934 - accuracy: 0.8910
# Epoch 6/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2847 - accuracy: 0.8945
# Epoch 7/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2713 - accuracy: 0.8983
# Epoch 8/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2597 - accuracy: 0.9046
# Epoch 9/20
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2520 - accuracy: 0.9049
# Epoch 10/20
# ...
